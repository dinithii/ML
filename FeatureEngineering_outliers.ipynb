# %% [markdown]
# <a href="https://colab.research.google.com/github/dinithii/ML/blob/main/FeatureEngineering_outliers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/ML/heights.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#     name  height
# 0  mohan     5.9
# 1  maria     5.2
# 2  sakib     5.1
# 3    tao     5.5
# 4  virat     4.9

# %%
max_threshold = df ['height'].quantile(0.95)
max_threshold
# Out:
# np.float64(9.689999999999998)

# %%
df[df['height']>max_threshold]
# Out:
#     name  height
# 9  imran    14.5

# %%
min_threshold = df ['height'].quantile(0.05)
min_threshold
# Out:
# np.float64(3.6050000000000004)

# %%
df[df['height']<min_threshold]
# Out:
#       name  height
# 12  yoseph     1.2

# %% [markdown]
# # Remove outliers

# %%
df[(df['height']<max_threshold) & (df['height']>min_threshold)]
# Out:
#        name  height
# 0     mohan     5.9
# 1     maria     5.2
# 2     sakib     5.1
# 3       tao     5.5
# 4     virat     4.9
# 5    khusbu     5.4
# 6    dmitry     6.2
# 7    selena     6.5
# 8      john     7.1
# 10     jose     6.1
# 11  deepika     5.6
# 13    binod     5.5

# %% [markdown]
# # Example 2

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/ML/bhp.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft
# 0            3699
# 1            4615
# 2            4305
# 3            6245
# 4            4250

# %%
df.shape
# Out:
# (13200, 7)

# %%
df.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13200.000000  13200.000000  13200.000000  13200.000000    1.320000e+04
# mean    1555.302783      2.691136    112.276178      2.800833    7.920337e+03
# std     1237.323445      1.338915    149.175995      1.292843    1.067272e+05
# min        1.000000      1.000000      8.000000      1.000000    2.670000e+02
# 25%     1100.000000      2.000000     50.000000      2.000000    4.267000e+03
# 50%     1275.000000      2.000000     71.850000      3.000000    5.438000e+03
# 75%     1672.000000      3.000000    120.000000      3.000000    7.317000e+03
# max    52272.000000     40.000000   3600.000000     43.000000    1.200000e+07

# %%
min_threshold, max_threshold = df.price_per_sqft.quantile([0.001,0.999])
min_threshold, max_threshold
# Out:
# (1366.184, 50959.36200000098)

# %%
df[df.price_per_sqft<min_threshold]
# Out:
#         location       size  total_sqft  bath  price  bhk  price_per_sqft
# 665    Yelahanka      3 BHK     35000.0   3.0  130.0    3             371
# 798        other  4 Bedroom     10961.0   4.0   80.0    4             729
# 1867       other  3 Bedroom     52272.0   2.0  140.0    3             267
# 2392       other  4 Bedroom      2000.0   3.0   25.0    4            1250
# 3934       other      1 BHK      1500.0   1.0   19.5    1            1300
# 5343       other      9 BHK     42000.0   8.0  175.0    9             416
# 5417      Ulsoor      4 BHK     36000.0   4.0  450.0    4            1250
# 5597    JP Nagar      2 BHK      1100.0   1.0   15.0    2            1363
# 7166   Yelahanka  1 Bedroom     26136.0   1.0  150.0    1             573
# 7862    JP Nagar      3 BHK     20000.0   3.0  175.0    3             875
# 8300     Kengeri      1 BHK      1200.0   1.0   14.0    1            1166
# 9144       other  4 Bedroom     10961.0   4.0   80.0    4             729
# ...

# %%
df[df.price_per_sqft>max_threshold]
# Out:
#                 location       size  total_sqft  bath   price  bhk  \
# 345                other  3 Bedroom        11.0   3.0    74.0    3
# 1005               other      1 BHK        15.0   1.0    30.0    1
# 1106               other  5 Bedroom        24.0   2.0   150.0    5
# 4044      Sarjapur  Road  4 Bedroom         1.0   4.0   120.0    4
# 4924               other      7 BHK         5.0   7.0   115.0    7
# 5911         Mysore Road  1 Bedroom        45.0   1.0    23.0    1
# 6356        Bommenahalli  4 Bedroom      2940.0   3.0  2250.0    4
# 7012               other      1 BHK       650.0   1.0   500.0    1
# 7575               other      1 BHK       425.0   1.0   750.0    1
# 7799               other      4 BHK      2000.0   3.0  1063.0    4
# 8307   Bannerghatta Road      5 BHK      2500.0   4.0  1400.0    5
# 9436        Indira Nagar  4 Bedroom      2400.0   5.0  1250.0    4
# 11447         Whitefield  4 Bedroom        60.0   4.0   218.0    4
# ...

# %%
df2 = df[(df.price_per_sqft<max_threshold) & (df.price_per_sqft>min_threshold)]
df2.shape
# Out:
# (13172, 7)

# %%
df2.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13172.000000  13172.000000  13172.000000  13172.000000    13172.000000
# mean    1537.861049      2.690100    111.591865      2.799651     6663.653735
# std      967.123711      1.337026    145.372047      1.291130     4141.020700
# min      250.000000      1.000000      8.000000      1.000000     1379.000000
# 25%     1100.000000      2.000000     50.000000      2.000000     4271.000000
# 50%     1274.500000      2.000000     71.550000      3.000000     5438.000000
# 75%     1670.000000      3.000000    120.000000      3.000000     7311.000000
# max    30400.000000     40.000000   3600.000000     43.000000    50349.000000

# %% [markdown]
# # Example 3

# %%
# !pip install kaggle

# %%
import json
import os

# Load the Kaggle API key
with open("kaggle.json", "r") as f:
    kaggle_creds = json.load(f)

# Set up Kaggle API authentication
os.environ['KAGGLE_USERNAME'] = kaggle_creds['username']
os.environ['KAGGLE_KEY'] = kaggle_creds['key']

# %%
# !kaggle datasets download -d dgomonov/new-york-city-airbnb-open-data
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dgomonov/new-york-city-airbnb-open-data
# License(s): CC0-1.0
# ...
#   0% 0.00/2.44M [00:00<?, ?B/s]
# 100% 2.44M/2.44M [00:00<00:00, 773MB/s]

# %%
import zipfile

with zipfile.ZipFile('new-york-city-airbnb-open-data.zip', 'r') as zip_ref:
    zip_ref.extractall()

# %%
import pandas as pd

df = pd.read_csv('AB_NYC_2019.csv')
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
min_threshold, max_threshold = df.price.quantile([0.01, 0.999])
min_threshold, max_threshold
# Out:
# (30.0, 3000.0)

# %%
df[df.price<min_threshold]
# Out:
#              id                                             name    host_id  \
# 957      375249                  Enjoy Staten Island Hospitality    1887999
# 2675    1428154              Central, Peaceful Semi-Private Room    5912572
# 2860    1620248    Large furnished 2 bedrooms- - 30 days Minimum    2196224
# 3020    1767037               Small Cozy Room Wifi & AC near JFK    9284163
# 3918    2431607                    Bright, Airy Room Share for 2    4973668
# ...         ...                                              ...        ...
# 48486  36280646                     Cable and wfi, L/G included.  272872092
# 48647  36354776    Cozy bedroom in diverse neighborhood near JFK  273393150
# 48832  36450814                         FLATBUSH HANG OUT AND GO  267223765
# 48867  36473044  The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                     Heaven for you(only for guy)  261338177
#
# ...

# %%
df[df.price>max_threshold]
# Out:
#              id                                               name    host_id  \
# 1862     826690                   Sunny, Family-Friendly 2 Bedroom    4289240
# 2698    1448703                Beautiful 1 Bedroom in Nolita/Soho      213266
# 3537    2110145                 UWS 1BR w/backyard + block from CP    2151325
# 3695    2224896                NYC SuperBowl Wk 5 Bdrs River View    11353904
# 3720    2243699                SuperBowl Penthouse Loft 3,000 sqft    1483320
# 3774    2271504                   SUPER BOWL Brooklyn Duplex Apt!!   11598359
# 3788    2281142                 Prime NYC Location for Super Bowl     1427243
# 4345    2919330                   NearWilliamsburg bridge 11211 BK   14908606
# 4376    2952861                               Photography Location    1177497
# 4377    2953058                                      Film Location    1177497
# 6530    4737930                                 Spanish Harlem Apt    1235070
# ...

# %%
df2 = df[(df.price<max_threshold) & (df.price>min_threshold)]
df2.shape
# Out:
# (48183, 16)

# %%
df2.sample(5)
# Out:
#              id                                               name    host_id  \
# 43012  33398320                      Residence Near JFK (T1F/ TB4)  145727343
# 19457  15521674                         Nice Room in Charming Apt.    8338942
# 34436  27308088  Sunny, Cozy & Clean Brooklyn Apt Steps from Train   42637974
# 27230  21516275  UES Modern Style 1 Bedroom Near 2 Ave Subway Line  156352453
# 23983  19342731   Private Room Avail.  Now- Aug 20 Clinton/BedStuy  132958806
#
#        host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 43012    Janelle              Queens             Jamaica  40.68324  -73.79169
# 19457     Victor           Manhattan              Nolita  40.72228  -73.99582
# 34436  Valentina            Brooklyn       Crown Heights  40.67782  -73.94740
# 27230      Lyjah           Manhattan     Upper East Side  40.76667  -73.95870
# 23983    Shannon            Brooklyn  Bedford-Stuyvesant  40.69140  -73.95993
#
# ...

# %%
df2.price.describe()
# Out:
# count    48183.000000
# mean       148.772036
# std        153.594795
# min         31.000000
# 25%         70.000000
# 50%        110.000000
# 75%        179.000000
# max       2999.000000
# Name: price, dtype: float64
